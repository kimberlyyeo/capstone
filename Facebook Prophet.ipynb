# %% [markdown]
# # Facebook Prophet
# - Author: Kimberly Yeo
# - Module: Capstone
# - Date: 2/11/2021

# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np
import math
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from fbprophet import Prophet
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, q_stat, adfuller
from arch import arch_model
from arch.univariate import ARCH, GARCH, ConstantMean, Normal
from sklearn.metrics import mean_absolute_error, mean_squared_error
# Out:
# Importing plotly failed. Interactive plots will not work.

# %% [markdown]
# ## Load data

# %% [markdown]
# For later iterations and testing, use cctx (it supports live data and multiple exchanges (best one is ftx)).

# %%
df = pd.read_csv("BTC-USD.csv")
df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-09-29  6643.100098  6643.100098  6511.649902  6601.959961
# 1  2018-09-30  6604.709961  6643.779785  6566.540039  6625.560059
# 2  2018-10-01  6619.850098  6653.299805  6549.080078  6589.620117
# 3  2018-10-02  6593.240234  6611.839844  6537.899902  6556.100098
# 4  2018-10-03  6553.859863  6571.459961  6454.029785  6502.589844
#
#      Adj Close        Volume
# 0  6601.959961  4.363690e+09
# 1  6625.560059  4.002280e+09
# 2  6589.620117  4.000970e+09
# 3  6556.100098  3.979260e+09
# 4  6502.589844  3.887310e+09

# %%
# Calculate daily returns as percentage price changes
df["Return"] = 100 * (df["Adj Close"].pct_change())
df["Log_Return"] = np.log(df["Adj Close"]).diff().mul(100) # rescale to faciliate optimization
df = df.dropna()

# %%
data = df[["Date", "Return"]]
data = data.set_index(data.columns[0])
data.head()
# Out:
#               Return
# Date
# 2018-09-30  0.357471
# 2018-10-01 -0.542444
# 2018-10-02 -0.508679
# 2018-10-03 -0.816190
# 2018-10-04  1.139547

# %% [markdown]
# ## EDA

# %%
# Plot daily returns
plt.figure(figsize = [25, 10])
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=30))
plt.plot(data)
plt.gcf().autofmt_xdate()
plt.show()

# %% [markdown]
# ## Forecasting Using Facebook Prophet

# %%
# Calculate the observed variance
obs_vol = data.sub(data.mean()).pow(2)

# %%
# Change column names to fit prophet requirements
obs_vol = obs_vol.reset_index()
obs_vol = obs_vol.rename(columns={'Date': 'ds', 'Return': 'y'})

# %%
train = obs_vol[:-29].dropna()
test = obs_vol[-29:].dropna()

# %%
# Define the model
model = Prophet()
# Fit the model
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Use the model to make a forecast
forecast = model.predict(pd.DataFrame(test['ds']))
# Summarize the forecast
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head())
# Out:
#           ds       yhat  yhat_lower  yhat_upper
# 0 2021-09-01  11.802438  -55.093184   76.018354
# 1 2021-09-02  21.294997  -44.816588   84.518906
# 2 2021-09-03   9.069867  -58.193850   79.678529
# 3 2021-09-04   3.439238  -62.202210   67.285675
# 4 2021-09-05   6.867525  -61.417520   71.949446

# %%
# Plot the forecast
model.plot(forecast)
plt.show()

# %%
# Calculate MAE between expected and predicted values for test data
y_true = test['y'].values
y_pred = forecast['yhat'].values
mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
print('MAE: %.3f' % mae)
print('MSE: %.3f' % mse)
# Out:
# MAE: 15.944
# MSE: 860.801

# %% [markdown]
# The MAE value is lower when compared to those of ARCH and GARCH models.

# %%
# Plot expected vs actual
plt.plot(y_true, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# It appears the model has trouble predicting large swings in volatility.

# %%
# Incorporating uncertainty in the trend
forecast = Prophet(interval_width=0.95).fit(train).predict(pd.DataFrame(test['ds']))
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Plot the forecast
model.plot(forecast)
plt.show()

# %%
# Incorporating uncertainty in seasonality
m = Prophet(mcmc_samples=300)
forecast = m.fit(train).predict(pd.DataFrame(test['ds']))
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
fig = m.plot_components(pd.DataFrame(test['ds']))
